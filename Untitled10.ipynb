# %%
import pandas as pd
import numpy as np

# %%
eng = pd.read_csv("eng.csv")
state = pd.read_csv("state.csv")
party = pd.read_csv("https://andybek.com/pandas-party")
liberal = pd.read_csv("liberal_arts.csv")
ivies = pd.read_csv("ivies.csv")

# %%
ivies.head()
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00

# %%
dfs = [eng, state, party, liberal, ivies]

# %%
schools = pd.concat(dfs).drop_duplicates(subset= ["School Name"])

# %%
schools.reset_index(drop= True, inplace= True)

# %%
ivies2 = ivies.sort_values(by= ["Starting Median Salary"], ascending= False)[:5].reset_index(drop= True)

# %%
eng2 = eng.sort_values(by= ["Starting Median Salary"], ascending= False)[:5].reset_index(drop= True)

# %%
pd.concat([ivies2, eng2], axis= 1)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0        Princeton University  Ivy League            $66,500.00
# 1          Harvard University  Ivy League            $63,400.00
# 2  University of Pennsylvania  Ivy League            $60,900.00
# 3          Cornell University  Ivy League            $60,300.00
# 4         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary                                   School Name  \
# 0             $131,000.00       California Institute of Technology (CIT)
# 1             $124,000.00    Massachusetts Institute of Technology (MIT)
# 2             $120,000.00                            Harvey Mudd College
# 3             $110,000.00   Polytechnic University of New York, Brooklyn
# 4             $107,000.00                                   Cooper Union
#
#    School Type Starting Median Salary Mid-Career Median Salary
# 0  Engineering            $75,500.00              $123,000.00
# ...

# %%
eng2["STEM"] = True

# %%
pd.concat([eng2, ivies])
# Out:
#                                     School Name  School Type  \
# 0      California Institute of Technology (CIT)  Engineering
# 1   Massachusetts Institute of Technology (MIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
# 0                             Dartmouth College   Ivy League
# 1                          Princeton University   Ivy League
# 2                               Yale University   Ivy League
# 3                            Harvard University   Ivy League
# 4                    University of Pennsylvania   Ivy League
# 5                            Cornell University   Ivy League
# 6                              Brown University   Ivy League
# 7                           Columbia University   Ivy League
#
#   Starting Median Salary Mid-Career Median Salary  STEM
# ...

# %%
new_df = pd.concat([liberal, state])

# %%
new_df["School Name"].nunique()
# Out:
# 222

# %%
new_df_mean = new_df["Starting Median Salary"].str.replace("$", "", regex= True).replace(",", "", regex= True).astype(float).mean()
print(f"Mean for Starting Median Salary in new_df is {new_df_mean}")
# Out:
# Mean for Starting Median Salary in new_df is 44469.36936936937

# %%
liberal["Mid-Career Salary"] = liberal["Mid-Career Median Salary"].str.replace("$", "", regex= True).replace(",", "", regex= True).astype(float)

# %%
top_3_liberal = liberal.sort_values(by= "Mid-Career Salary", ascending= False)[:3]

# %%
state["Mid-Career Salary"] = state["Mid-Career Median Salary"].str.replace("$", "", regex= True).replace(",", "", regex= True).astype(float)

# %%
top_3_state = state.sort_values(by= "Mid-Career Salary", ascending= False)[:3]

# %%
pd.concat([top_3_liberal[["School Name", "Mid-Career Salary"]], top_3_state[["School Name", "Mid-Career Salary"]]], axis= 1).reset_index(drop= True)
# Out:
#            School Name  Mid-Career Salary                         School Name  \
# 0  Bucknell University           110000.0  University of California, Berkeley
# 1   Colgate University           108000.0        University of Virginia (UVA)
# 2      Amherst College           107000.0            Cal Poly San Luis Obispo
#
#    Mid-Career Salary
# 0           112000.0
# 1           103000.0
# 2           101000.0

# %%
regions_url = "https://andybek.com/pandas-regions"

# %%
regions = pd.read_csv(regions_url)

# %%
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
pd.merge(schools, regions, on= "School Name")
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $72,200.00              $126,000.00   Northeastern
# 1              $75,500.00              $123,000.00     California
# ...

# %%
income_df = pd.read_csv("https://andybek.com/pandas-mid")

# %%
income_df.isnull().sum()
# Out:
# school_name                           0
# Mid-Career 10th Percentile Salary    38
# Mid-Career 25th Percentile Salary     0
# Mid-Career 75th Percentile Salary     0
# Mid-Career 90th Percentile Salary    38
# dtype: int64

# %%
pd.merge(schools, income_df, left_on= "School Name", right_on= "school_name").drop("school_name", axis= 1)
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# ...

# %%
schools.head(

)
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $62,400.00              $114,000.00
# 4            $62,200.00              $114,000.00

# %%
income_df.head()
# Out:
#                                     school_name  \
# 0   Massachusetts Institute of Technology (MIT)
# 1      California Institute of Technology (CIT)
# 2                           Harvey Mudd College
# 3  Polytechnic University of New York, Brooklyn
# 4                                  Cooper Union
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $76,800.00                        $99,200.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $66,800.00                        $94,300.00
# 4                               NaN                       $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $168,000.00                       $220,000.00
# 1                      $161,000.00                                NaN
# ...

# %%
pd.merge(ivies, regions, how= "outer")
# Out:
#                              School Name School Type Starting Median Salary  \
# 0                      Dartmouth College  Ivy League            $58,000.00
# 1                   Princeton University  Ivy League            $66,500.00
# 2                        Yale University  Ivy League            $59,100.00
# 3                     Harvard University  Ivy League            $63,400.00
# 4             University of Pennsylvania  Ivy League            $60,900.00
# ..                                   ...         ...                    ...
# 264         Austin Peay State University         NaN                    NaN
# 265           Pittsburg State University         NaN                    NaN
# 266             Southern Utah University         NaN                    NaN
# 267  Montana State University - Billings         NaN                    NaN
# 268         Black Hills State University         NaN                    NaN
#
#     Mid-Career Median Salary        Region
# ...

# %%
# Many-To-Many Merge

# %%
df_many_1 = pd.DataFrame({'City': ['New York', 'Los Angeles', 'Chicago', 'New York'],
                    'Population': [8_398_748, 3_990_456, 2_705_994, 8_398_748]})

df_many_2 = pd.DataFrame({'City': ['New York', 'Los Angeles', 'New York', 'Chicago'],
                    'Attraction': ['Central Park', 'Hollywood', 'Empire State Building', 'Millennium Park']})

# %%
many_to_many = pd.merge(df_many_1, df_many_2, on= "City")

# %%
many_to_many.head()
# Out:
#           City  Population             Attraction
# 0     New York     8398748           Central Park
# 1     New York     8398748  Empire State Building
# 2     New York     8398748           Central Park
# 3     New York     8398748  Empire State Building
# 4  Los Angeles     3990456              Hollywood

# %%
# Merge the liberal arts schools with regions and assign the resulting dataframe to dfm. what region has the highest number of liberal arts school

# %%
dfm = pd.merge(liberal, regions)

# %%
dfm["Region"].value_counts()
# Out:
# Northeastern    25
# Midwestern       8
# Western          7
# Southern         5
# California       3
# Name: Region, dtype: int64

# %%
# Set the school name as the index of the mid-career dataframe. Do the operation inplace.
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary  Mid-Career Salary        Region
# 0             $110,000.00            110000.0  Northeastern
# 1             $108,000.00            108000.0  Northeastern
# 2             $107,000.00            107000.0  Northeastern
# 3             $107,000.00            107000.0  Northeastern
# 4             $107,000.00            107000.0  Northeastern

# %%
mid_career = pd.read_csv("https://andybek.com/pandas-mid")

# %%
mid_career.set_index("school_name", inplace= True)

# %%
# merge the dfm and the mid career dfs; is it a one-to-one operation(no)?

# %%
merged_dfm = pd.merge(dfm, mid_career, left_on= "School Name", right_index= True)

# %%
merged_dfm[merged_dfm.duplicated()]
# Out:
#                School Name   School Type Starting Median Salary  \
# 28  Randolph-Macon College  Liberal Arts            $42,600.00
# 29  Randolph-Macon College  Liberal Arts            $42,600.00
# 29  Randolph-Macon College  Liberal Arts            $42,600.00
#
#    Mid-Career Median Salary  Mid-Career Salary    Region  \
# 28              $83,600.00             83600.0  Southern
# 29              $83,600.00             83600.0  Southern
# 29              $83,600.00             83600.0  Southern
#
#    Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 28                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
#
#    Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 28                      $123,000.00                                NaN
# ...

# %%
mid_career[mid_career.duplicated()]
# Out:
#                                                   Mid-Career 10th Percentile Salary  \
# school_name
# Randolph-Macon College                                                          NaN
# University of Illinois at Urbana-Champaign (UIUC)                       $48,200.00
# University of Maryland, College Park                                    $50,400.00
# University of California, Santa Barbara (UCSB)                          $51,300.00
# University of Texas (UT) - Austin                                       $50,100.00
# State University of New York (SUNY) at Albany                           $47,000.00
# University of Florida (UF)                                              $45,400.00
# Louisiana State University (LSU)                                        $43,700.00
# University of Georgia (UGA)                                             $43,100.00
# Pennsylvania State University (PSU)                                     $46,300.00
# ...

# %%
mid_career.loc[mid_career.index == "Randolph-Macon College"]
# Out:
#                        Mid-Career 10th Percentile Salary  \
# school_name
# Randolph-Macon College                               NaN
# Randolph-Macon College                               NaN
#
#                        Mid-Career 25th Percentile Salary  \
# school_name
# Randolph-Macon College                       $54,100.00
# Randolph-Macon College                       $54,100.00
#
#                        Mid-Career 75th Percentile Salary  \
# school_name
# Randolph-Macon College                      $123,000.00
# Randolph-Macon College                      $123,000.00
#
#                        Mid-Career 90th Percentile Salary
# school_name
# Randolph-Macon College                               NaN
# Randolph-Macon College                               NaN

# %%
dfm.loc[dfm["School Name"] == "Randolph-Macon College"]
# Out:
#                School Name   School Type Starting Median Salary  \
# 28  Randolph-Macon College  Liberal Arts            $42,600.00
# 29  Randolph-Macon College  Liberal Arts            $42,600.00
#
#    Mid-Career Median Salary  Mid-Career Salary    Region
# 28              $83,600.00             83600.0  Southern
# 29              $83,600.00             83600.0  Southern

# %%
merged_dfm[merged_dfm.duplicated(keep= False)]
# Out:
#                School Name   School Type Starting Median Salary  \
# 28  Randolph-Macon College  Liberal Arts            $42,600.00
# 28  Randolph-Macon College  Liberal Arts            $42,600.00
# 29  Randolph-Macon College  Liberal Arts            $42,600.00
# 29  Randolph-Macon College  Liberal Arts            $42,600.00
#
#    Mid-Career Median Salary  Mid-Career Salary    Region  \
# 28              $83,600.00             83600.0  Southern
# 28              $83,600.00             83600.0  Southern
# 29              $83,600.00             83600.0  Southern
# 29              $83,600.00             83600.0  Southern
#
#    Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 28                               NaN                       $54,100.00
# 28                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
#
# ...

# %%
mid_career[mid_career.duplicated(keep= False).index == "Randolph-Macon College"]
# Out:
#                        Mid-Career 10th Percentile Salary  \
# school_name
# Randolph-Macon College                               NaN
# Randolph-Macon College                               NaN
#
#                        Mid-Career 25th Percentile Salary  \
# school_name
# Randolph-Macon College                       $54,100.00
# Randolph-Macon College                       $54,100.00
#
#                        Mid-Career 75th Percentile Salary  \
# school_name
# Randolph-Macon College                      $123,000.00
# Randolph-Macon College                      $123,000.00
#
#                        Mid-Career 90th Percentile Salary
# school_name
# Randolph-Macon College                               NaN
# Randolph-Macon College                               NaN

# %%
merged_dfm.shape
# Out:
# (50, 10)

# %%
dfm.columns
# Out:
# Index(['School Name', 'School Type', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career Salary', 'Region'],
#       dtype='object')

# %%
mid_career.columns
# Out:
# Index(['Mid-Career 10th Percentile Salary',
#        'Mid-Career 25th Percentile Salary',
#        'Mid-Career 75th Percentile Salary',
#        'Mid-Career 90th Percentile Salary'],
#       dtype='object')

# %%
merged_dfm.columns
# Out:
# Index(['School Name', 'School Type', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career Salary', 'Region',
#        'Mid-Career 10th Percentile Salary',
#        'Mid-Career 25th Percentile Salary',
#        'Mid-Career 75th Percentile Salary',
#        'Mid-Career 90th Percentile Salary'],
#       dtype='object')
